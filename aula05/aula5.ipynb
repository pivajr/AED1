# %%
print("Olá Mundo!")
# Out:
# Olá Mundo!

# %%
5+5
# Out:
# 10

# %%
nome = "Piva"

# %%
nome
# Out:
# 'Piva'

# %%
print(nome)
# Out:
# Piva

# %%
x = 345

# %%
y = x + 2

# %%
y
# Out:
# 347

# %%
a = 5

# %%
type(a)
# Out:
# int

# %%
a = True

# %%
type(a)
# Out:
# bool

# %%
a = 5.6

# %%
type(a)
# Out:
# float

# %%
x = 45
y = 23

# %%
soma = x + y 
divisao = x / y

# %%
type(divisao)
# Out:
# float

# %%
divisao
# Out:
# 1.9565217391304348

# %%
type(soma)
# Out:
# int

# %%
print(soma)
# Out:
# 68

# %%
x / y
# Out:
# 1.9565217391304348

# %%
x // y
# Out:
# 1

# %%
x % y
# Out:
# 22

# %%
r = 10_000_000_000

# %%
r
# Out:
# 10000000000

# %%
x ** y
# Out:
# 105654455657631171893227100372314453125

# %%
x = 111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111
y = x ** 2

# %%
x
# Out:
# 111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111

# %%
y
# Out:
# 

# %%
y = 4.9

# %%
type(y)
# Out:
# float

# %%
int(y)
# Out:
# 4

# %%
x = True

# %%
x
# Out:
# True

# %%
y = False

# %%
x and y
# Out:
# False

# %%
x or y
# Out:
# True

# %%
not x
# Out:
# False

# %%
nome = 'Piva'

# %%
type(nome)
# Out:
# str

# %%
prenome = "Dilermando 'piva' "

# %%
nome_completo = prenome + nome

# %%
nome_completo
# Out:
# "Dilermando 'piva' Piva"

# %%
nome * 4
# Out:
# 'PivaPivaPivaPiva'

# %%
nome[0]
# Out:
# 'P'

# %%
nome[0:2]
# Out:
# 'Pi'

# %%
chr(65)
# Out:
# 'A'

# %%
chr(97)
# Out:
# 'a'

# %%
ord('a')
# Out:
# 97
