# %%
idade = int(input("Digite sua idade: "))
carro = input("Tem carro? <S/N> ")
if idade >= 18:
    if carro == "S":
        print("Pode Dirigir!!")
    else:
        print("Chama o Uber!!")
else:
    print("Chama o Uber!!")
# Out:
# Digite sua idade:  45
# Tem carro? <S/N>  N
# Chama o Uber!!

# %%
idade = int(input("Digite sua idade: "))
carro = input("Tem carro? <S/N> ")
if (idade >= 18) and (carro == "S"):
    print("Pode Dirigir!!")
else:
    print("Chama o Uber!!")
# Out:
# Digite sua idade:  17
# Tem carro? <S/N>  S
# Chama o Uber!!

# %%
idade = int(input("Digite sua idade: "))
if idade >= 18:
    carro = input("Tem carro? <S/N> ")
    if carro == "S":
        print("Pode Dirigir!!")
    print("Chama o Uber!!")
else:
    print("Chama o Uber!!")

# %%
nota1 = float(input("Digite a nota 1: "))
nota2 = float(input("Digite a nota 2: "))
media = (nota1 + nota2) / 2
print("A média é igual a : ", media)
if media >= 5:
    print("Aprovado(a)!")
else:
    print("Reprovado(a)")
# Out:
# Digite a nota 1:  6
# Digite a nota 2:  3
# A média é igual a :  4.5
# Reprovado(a)

# %%
nota1 = float(input("Digite a nota 1: "))
if nota1 >= 7:
    nota1 += 0.5
nota2 = float(input("Digite a nota 2: "))
if nota2 >= 7:
    nota2 = nota2 + 0.5
media = (nota1 + nota2) / 2
print("A média é igual a : ", media)
if media >= 5:
    print("Aprovado(a)!")
else:
    print("Reprovado(a)")
# Out:
# Digite a nota 1:  8
# Digite a nota 2:  9
# A média é igual a :  9.0
# Aprovado(a)!

# %% [markdown]
# Faça um programa que peça os 3 lados de um triangulo. O programa deve informar se os valores podem ser um triângulo. Indique, caso os lados formem um triângulo se o mesmo é: equilátero, isosceles ou escaleno.

# %%
print("Digite os lados de um triângulo: ")
a = float(input("Entre com o lado a: "))
b = float(input("Entre com o lado b: "))
c = float(input("Entre com o lado c: "))
if (a >= b+c) or (b >= a+c) or (c >= a+b):   
    print("Não é um triângulo")
else:
    if (a == b == c):
        print("Triângulo Equilátero!")
    elif (a == b) or (b == c) or (a == c):
        print("Triângulo Isósceles!")
    else:
        print("Triângulo Escaleno!")

# %%
if (a+b > c) and (b+c > a) and (a+c > b):
    if (a == b == c):
        print("Triângulo Equilátero!")
    elif (a == b) or (b == c) or (a == c):
        print("Triângulo Isósceles!")
    else:
        print("Triângulo Escaleno!")
else:
    print("Não é um triangulo")
