# %%
x = -90
print(abs(x))

# %%
print(x)

# %%
print(chr(65))

# %%
print(chr(167))

# %%
print(ord('A'))

# %%
import math

# %%
math.pow(4, 2)

# %%
from math import pow, sqrt

# %%
pow(5,3)

# %%
sqrt(25)
