# %%
ord("A")
# Out:
# 65

# %%
chr(65)
# Out:
# 'A'

# %%
format(65, '08b')
# Out:
# '01000001'

# %%
ord("B")
# Out:
# 66

# %%
print(format(ord("P"), "08b"))
print(format(ord("i"), "08b"))
print(format(ord("v"), "08b"))
print(format(ord("a"), "08b"))
# Out:
# 01010000
# 01101001
# 01110110
# 01100001

# %%
for letra in "Piva":
  codigo = ord(letra)
  binario = format(codigo, "08b")
  print(letra, "-->", codigo, "-->", binario)
# Out:
# P --> 80 --> 01010000
# i --> 105 --> 01101001
# v --> 118 --> 01110110
# a --> 97 --> 01100001
