# %%
flag = 1
while flag <= 5:
    print("Olá!!")
    flag = flag + 1
# Out:
# Olá!!
# Olá!!
# Olá!!
# Olá!!
# Olá!!

# %%
for x in range(1, 10):
    print(x)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
nome = input("Digite seu nome: ")
for letra in nome:
    print(letra)
# Out:
# Digite seu nome:  Piva
# P
# i
# v
# a
